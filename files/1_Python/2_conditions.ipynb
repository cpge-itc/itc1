# %% [markdown]
# # <center><a href='https://notebook.basthon.fr/?from=https://raw.githubusercontent.com/fortierq/itc1/master/files/1_Python/2_conditions.ipynb'><center><a href='https://mybinder.org/v2/gh/fortierq/itc-binder/main?urlpath=git-pull%3Frepo%3Dhttps%253A%252F%252Fgithub.com%252Ffortierq%252Fitc1%26urlpath%3Dlab%252Ftree%252Fitc1%252Ffiles%252F1_Python%252F2_conditions.ipynb%26branch%3Dmaster'>Condition if <img src=https://mybinder.org/badge_logo.svg></a></center> <img src=https://framagit.org/uploads/-/system/project/avatar/55763/basthon_shadow.png width=100></a></center>
#
# On peut écrire une condition `if` de la façon suivante en Python :
# ```python
# if condition:
#     instruction
# ```

# %% [markdown]
# On peut aussi utiliser `else` pour spécifier ce qui passe si la condition est fausse :

# %%
if 1 < 2:
    print("You don't say?")
else:
    print("??!!")
# Out:
# You don't say?

# %% [markdown]
# Donnons un exemple un peu plus utile : l'implémentation de la fonction valeur absolue ($x \longmapsto \vert x \vert$).

# %%
def abs(x):
    if x < 0:
        return -x
    return x  # le else n'est pas obligatoire

# %% [markdown]
# **Exercice** : Écrire une fonction `n_solutions` telle que `n_solutions(a, b, c)` renvoie le nombre de solutions de $ax^2 + bx + c = 0$.

# %%
def n_solutions(a, b, c):
    delta = b**2 - 4*a*c
    if abs(delta) < 0.0001: # attention : il ne faut pas tester l'égalité de 2 flottants à cause des erreurs d'arrondis
        return 1
    if delta > 0: # on pourrait mettre un else mais ce n'est pas nécessaire
        return 2
    return 0

# %% [markdown]
# **Exercice** : Écrire une fonction Python correspondant à chacune des représentations graphiques ci-dessous.
# *Indice : la 3ème fonction est égale à* $x \longmapsto \vert x - 1 \vert$ *sur l'intervalle* $[0, \infty[$.

# %% [markdown]
# <img src="data:image/png;base64,...">

# %%
def f1(x):
    if x < 2:
        return 5
    return 3

def f2(x):
    if x < -1:
        return -3
    if x < 1:
        return 3
    return 7

def f3(x):
    if x < 0:
        return 1
    return abs(x - 1)
