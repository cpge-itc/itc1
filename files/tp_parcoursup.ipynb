# %% [markdown]
# # Études statistiques sur Parcoursup
#
# Dans ce TP, nous allons explorer les données en libre accès issues de Parcoursup sur [https://data.enseignementsup-recherche.gouv.fr/explore/dataset/fr-esr-parcoursup](https://data.enseignementsup-recherche.gouv.fr/explore/dataset/fr-esr-parcoursup).
# Commençons par charger les données en utilisant le module pandas (particulièrement adapté en *data science*) en exécutant les deux cases suivantes :

# %%
import pandas as pd

url = "https://data.enseignementsup-recherche.gouv.fr/explore/dataset/fr-esr-parcoursup/download/?format=csv&timezone=Europe/Berlin&lang=fr&use_labels_for_header=true&csv_separator=%3B" # Lien du dataset

df = pd.read_csv(url, sep=";").iloc[:, [110, 3, 5, 7, 8, 9, 17, 45, 82, 83, 84, 85, 101, 107, 113, 114, 115]]

# %%
df = df.rename(columns={"% d’admis néo bacheliers sans mention au bac": "Sans mention", "% d’admis néo bacheliers avec mention Assez Bien au bac": "Mention Assez Bien", "% d’admis néo bacheliers avec mention Bien au bac": "Mention Bien", "% d’admis néo bacheliers avec mention Très Bien au bac": "Mention Très Bien", "Rang du dernier appelé du groupe 1": "Rang dernier appelé", "Taux d’accès des candidats ayant postulé à la formation (ratio entre le dernier appelé et le nombre vœux PP)": "Taux d'accès", "LIB_FOR_VOE_INS": "Filière", "Effectif total des candidats ayant accepté la proposition de l’établissement (admis)": "Effectif"})

# %% [markdown]
# `df` est un *dataframe* : un tableau de données. Voici un aperçu de `df` :

# %%
df
# Out:
#                                                  Filière  \
# 0      Licence - Portail Philosophie - Anthropologie ...
# 1                        D.E Assistant de Service Social
# 2      DN MADE - Graphisme - - Spécialité : Design gr...
# 3      Licence - Langues, littératures & civilisation...
# 4      Licence - Langues, littératures & civilisation...
# ...                                                  ...
# 13391  Licence - Langues, littératures & civilisation...
# 13392  Licence - Langues, littératures & civilisation...
# 13393  Licence - Langues, littératures & civilisation...
# 13394  Licence - Langues, littératures & civilisation...
# 13395  Licence - Portail Histoire - Géographie à dist...
#
#                                            Établissement  \
# 0      Aix Marseille Université - Site d'Aix-en-Provence
# 1      ECOLE PRATIQUE SERVICE SOCIAL CTRE POLYTECHN. ...
# 2                              Lycée De La Communication
# 3                   Université Sorbonne Nouvelle Paris 3
# 4                   Université Sorbonne Nouvelle Paris 3
# ...                                                  ...
# 13391  Aix Marseille Université - Site d'Aix-en-Provence
# 13392  Aix Marseille Université - Site d'Aix-en-Provence
# 13393               Université Sorbonne Nouvelle Paris 3
# 13394  Aix Marseille Université - Site d'Aix-en-Provence
# 13395  Aix Marseille Université - Site d'Aix-en-Provence
#
#       Département de l’établissement Académie de l’établissement  \
# 0                   Bouches-du-Rhône               Aix-Marseille
# 1                         Val-d'oise                  Versailles
# 2                            Moselle                  Nancy-Metz
# 3                              Paris                       Paris
# 4                              Paris                       Paris
# ...                              ...                         ...
# 13391               Bouches-du-Rhône               Aix-Marseille
# 13392               Bouches-du-Rhône               Aix-Marseille
# 13393                          Paris                       Paris
# 13394               Bouches-du-Rhône               Aix-Marseille
# 13395               Bouches-du-Rhône               Aix-Marseille
#
#       Commune de l’établissement              Sélectivité  \
# 0                Aix-en-Provence  formation non sélective
# 1                          Cergy      formation sélective
# 2                           Metz      formation sélective
# 3      Paris  5e  Arrondissement  formation non sélective
# 4      Paris  5e  Arrondissement  formation non sélective
# ...                          ...                      ...
# 13391            Aix-en-Provence  formation non sélective
# 13392            Aix-en-Provence  formation non sélective
# 13393  Paris  5e  Arrondissement  formation non sélective
# 13394            Aix-en-Provence  formation non sélective
# 13395            Aix-en-Provence  formation non sélective
#
#        Effectif total des candidats pour une formation  Effectif  \
# 0                                                  385        46
# 1                                                   72        30
# 2                                                  779        14
# 3                                                   55        14
# 4                                                   83        19
# ...                                                ...       ...
# 13391                                              108        18
# 13392                                              474        34
# 13393                                              338        36
# 13394                                              329        40
# 13395                                              324        35
#
#        Sans mention  Mention Assez Bien  Mention Bien  Mention Très Bien  \
# 0         14.298828           28.597656     14.298828               28.6
# 1         66.687500           13.298828     13.298828                6.7
# 2          0.000000           18.199219     45.500000               36.4
# 3         40.000000           60.000000      0.000000                0.0
# 4         45.500000           36.398438     18.199219                0.0
# ...             ...                 ...           ...                ...
# 13391     18.199219           63.593750      0.000000               18.2
# 13392     21.097656           42.093750     31.597656                5.3
# 13393     10.000000           40.000000     40.000000               10.0
# 13394     20.000000           20.000000     40.000000               20.0
# 13395     50.000000            0.000000     50.000000                0.0
#
#        Rang dernier appelé  Taux d'accès  \
# 0                    318.0          91.0
# 1                     43.0          65.0
# 2                    123.0          16.0
# 3                     42.0          98.0
# 4                     48.0         100.0
# ...                    ...           ...
# 13391                 66.0          99.0
# 13392                184.0          39.0
# 13393                142.0          42.0
# 13394                260.0          82.0
# 13395                292.0          94.0
#
#        Dont taux d’accès des candidats ayant un bac général ayant postulé à la formation  \
# 0                                                   78.0
# 1                                                   37.0
# 2                                                   79.0
# 3                                                   86.0
# 4                                                   63.0
# ...                                                  ...
# 13391                                               89.0
# 13392                                               94.0
# 13393                                               72.0
# 13394                                               78.0
# 13395                                               71.0
#
#        Dont taux d’accès des candidats ayant un bac technologique ayant postulé à la formation  \
# 0                                                    9.0
# 1                                                   37.0
# 2                                                   14.0
# 3                                                   14.0
# 4                                                   21.0
# ...                                                  ...
# 13391                                               11.0
# 13392                                                3.0
# 13393                                               11.0
# 13394                                               15.0
# 13395                                               23.0
#
#        Dont taux d’accès des candidats ayant un bac professionnel ayant postulé à la formation
# 0                                                    7.0
# 1                                                   23.0
# 2                                                    7.0
# 3                                                    0.0
# 4                                                   16.0
# ...                                                  ...
# 13391                                                0.0
# 13392                                                3.0
# 13393                                               14.0
# 13394                                                8.0
# 13395                                                3.0
#
# [13396 rows x 17 columns]

# %% [markdown]
# Chaque ligne correspond à une formation (13396 au total) et chaque colonne à un attribut. Par exemple, la première ligne correspond au lycée Sainte Famille	à Grenoble.
# `df.columns` est une liste contenant les noms des colonnes. Par exemple la première colonne est :

# %%
df.columns[0]
# Out:
# 'Filière'

# %% [markdown]
# **Exercice** : Afficher le nom de chaque colonne avec une boucle `for`.

# %% [markdown]
# ## Formation sélective ou non
#
# Une des colonnes de `df` est `"Sélectivité"` et indique si une formation est sélective ou pas (c'est-à-dire si les élèves sont sélectionnés suivant leur dossier) :

# %%
df["Sélectivité"] # liste des sélectivités ("formation sélective" "formation non sélective")
# Out:
# 0        formation non sélective
# 1            formation sélective
# 2            formation sélective
# 3        formation non sélective
# 4        formation non sélective
#                   ...
# 13391    formation non sélective
# 13392    formation non sélective
# 13393    formation non sélective
# 13394    formation non sélective
# 13395    formation non sélective
# Name: Sélectivité, Length: 13396, dtype: object

# %%
df["Sélectivité"][0] # indique la sélectivité de la 1ère formation
# Out:
# 'formation non sélective'

# %% [markdown]
# **Exercice** : Calculer le pourcentage de formations sélectives.

# %% [markdown]
# # Lycée Fénelon Sainte-Marie

# %% [markdown]
# Pour chercher des valeurs, on peut utiliser `query`. Par exemple, l'instruction suivante permet de récupérer toutes les MP2I de France :

# %%
df.query("Filière == 'CPGE - MP2I'")
# Out:
#            Filière                    Établissement  \
# 541    CPGE - MP2I                     Lycée Thiers
# 543    CPGE - MP2I             Lycée Claude Fauriel
# 544    CPGE - MP2I                  Lycée Descartes
# 545    CPGE - MP2I           Lycée Janson De Sailly
# 5235   CPGE - MP2I            Lycée Charles Coeffin
# 5236   CPGE - MP2I                    Lycée Colbert
# 5237   CPGE - MP2I                    Lycée du Parc
# 5275   CPGE - MP2I                     Lycée Carnot
# 5277   CPGE - MP2I             Lycée Louis Le Grand
# 5930   CPGE - MP2I                     Lycée Kléber
# 5968   CPGE - MP2I                Lycée Champollion
# 5969   CPGE - MP2I         Lycée général Clemenceau
# 5970   CPGE - MP2I  Lycée International de Valbonne
# 10549  CPGE - MP2I                Lycée Paul Valery
# 10590  CPGE - MP2I                Lycée Victor Hugo
# 10592  CPGE - MP2I                  Lycée Faidherbe
# 10593  CPGE - MP2I               Lycée Henri Wallon
# 10594  CPGE - MP2I       Lycée Fénelon Sainte-Marie
# 10595  CPGE - MP2I           Lycée Pierre De Fermat
# 12247  CPGE - MP2I                 Lycée Gay-Lussac
# 12248  CPGE - MP2I         Lycée Franklin Roosevelt
# 12286  CPGE - MP2I            Lycée Louis Thuillier
# 12287  CPGE - MP2I                  Lycée Montaigne
# 12288  CPGE - MP2I             Lycée Aux Lazaristes
# 12289  CPGE - MP2I         Lycée Saint-Louis (6ème)
# 12290  CPGE - MP2I                      Lycée Hoche
#
#       Département de l’établissement Académie de l’établissement  \
# 541                 Bouches-du-Rhône               Aix-Marseille
# 543                            Loire                        Lyon
# 544                   Indre-et-Loire               Orléans-Tours
# 545                            Paris                       Paris
# 5235                      Guadeloupe                  Guadeloupe
# 5236                            Nord                       Lille
# 5237                           Rhône                        Lyon
# 5275                       Côte-d'or                       Dijon
# 5277                           Paris                       Paris
# 5930                        Bas-Rhin                  Strasbourg
# 5968                           Isère                    Grenoble
# 5969                Loire-Atlantique                      Nantes
# 5970                 Alpes-Maritimes                        Nice
# 10549                          Paris                       Paris
# 10590                          Doubs                    Besancon
# 10592                           Nord                       Lille
# 10593                           Nord                       Lille
# 10594                          Paris                       Paris
# 10595                  Haute-Garonne                    Toulouse
# 12247                   Haute-Vienne                     Limoges
# 12248                          Marne                       Reims
# 12286                          Somme                      Amiens
# 12287                        Gironde                    Bordeaux
# 12288                          Rhône                        Lyon
# 12289                          Paris                       Paris
# 12290                       Yvelines                  Versailles
#
#           Commune de l’établissement          Sélectivité  \
# 541    Marseille  1er Arrondissement  formation sélective
# 543                    Saint-Etienne  formation sélective
# 544                            Tours  formation sélective
# 545        Paris 16e  Arrondissement  formation sélective
# 5235                    Baie-Mahault  formation sélective
# 5236                       Tourcoing  formation sélective
# 5237         Lyon 6e  Arrondissement  formation sélective
# 5275                           Dijon  formation sélective
# 5277       Paris  5e  Arrondissement  formation sélective
# 5930                      Strasbourg  formation sélective
# 5968                        Grenoble  formation sélective
# 541                                                100.0
# 543                                                100.0
# 544                                                100.0
# 545                                                100.0
# 5235                                               100.0
# 5236                                               100.0
# 5237                                               100.0
# 5275                                               100.0
# 5277                                               100.0
# 5930                                               100.0
# 5968                                               100.0
# 5969                                               100.0
# 5970                                               100.0
# 10549                                               98.0
# 10590                                              100.0
# 10592                                              100.0
# 10593                                              100.0
# 10594                                              100.0
# 10595                                              100.0
# 12247                                              100.0
# 12248                                              100.0
# 12286                                              100.0
# 12287                                              100.0
# 12288                                              100.0
# 12289                                              100.0
# 12290                                              100.0
#
#        Dont taux d’accès des candidats ayant un bac technologique ayant postulé à la formation  \
# 541                                                  0.0
# 543                                                  0.0
# 544                                                  0.0
# 545                                                  0.0
# 5235                                                 0.0
# 5236                                                 0.0
# 5237                                                 0.0
# 5275                                                 0.0
# 5277                                                 0.0
# 5930                                                 0.0
# 5968                                                 0.0
# 5969                                                 0.0
# 5970                                                 0.0
# 10549                                                2.0
# 10590                                                0.0
# 10592                                                0.0
# 10593                                                0.0
# 10594                                                0.0
# 10595                                                0.0
# 12247                                                0.0
# 12248                                                0.0
# 12286                                                0.0
# 12287                                                0.0
# 12288                                                0.0
# 12289                                                0.0
# 12290                                                0.0
#
#        Dont taux d’accès des candidats ayant un bac professionnel ayant postulé à la formation
# 541                                                  0.0
# 543                                                  0.0
# 544                                                  0.0
# 545                                                  0.0
# 5235                                                 0.0
# 5236                                                 0.0
# 5237                                                 0.0
# 5275                                                 0.0
# 5277                                                 0.0
# 5930                                                 0.0
# 5968                                                 0.0
# 5969                                                 0.0
# 5970                                                 0.0
# 10549                                                0.0
# 10590                                                0.0
# 10592                                                0.0
# 10593                                                0.0
# 10594                                                0.0
# 10595                                                0.0
# 12247                                                0.0
# 12248                                                0.0
# 12286                                                0.0
# 12287                                                0.0
# 12288                                                0.0
# 12289                                                0.0
# 12290                                                0.0

# %% [markdown]
# **Exercice** : Quelles sont les MP2I avec le plus/le moins d'élèves ?

# %% [markdown]
# **Exercice** : En utilisant `df.query` de façon similaire à ci-dessus, chercher toutes les formations correpondants à l'établissement "Lycée Fénelon Sainte-Marie". Quelle est la filière du lycée avec le plus de mentions TB ?

# %% [markdown]
# ## Effectif

# %% [markdown]
# `df["Effectif"]` donne l'effectif (nombre d'élèves) de chaque formation. Par exemple, pour obtenir l'effectif de la première formation :

# %%
df["Effectif"][0]
# Out:
# 46

# %% [markdown]
# **Exercice** : Quel est l'effectif moyen d'une formation en France ?

# %% [markdown]
# **Exercice** : Calculer l'effectif maximum et minimum d'une formation en France. Quels sont les noms des filières correspondantes ?

# %% [markdown]
# ## Filières en CPGE

# %% [markdown]
# On peut tester si une chaîne de caractère contient un mot en utilisant `in` :

# %%
"mat" in "informatique"
# Out:
# True

# %%
"math" in "informatique"
# Out:
# False

# %% [markdown]
# **Exercice** : Quel est le nombre de CPGE en France ? Et pour chaque filière de CPGE (MPSI, PCSI, MP2I, BCPST...) ?

# %% [markdown]
# ## Pourcentage de mentions Très Bien

# %% [markdown]
# **Exercice** : Combien y a t-il eu de mentions TB en France ?
# *Indice* : Il faut multiplier chaque pourcentage de mentions TB par l'effectif de la formation, puis prendre la somme.

# %% [markdown]
# # À vous de jouer !
#
# Chercher d'autres statistiques sur les données : pourcentage de bacheliers technologiques dans le supérieur, filière de CPGE la plus sélective...
