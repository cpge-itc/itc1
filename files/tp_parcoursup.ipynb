# %% [markdown]
# # Études statistiques sur Parcoursup
#
# ![](https://upload.wikimedia.org/wikipedia/fr/thumb/d/dc/Logo_parcoursup.svg/langfr-1920px-Logo_parcoursup.svg.png)
# Dans ce TP, nous allons explorer les données en libre accès issues de Parcoursup sur [https://data.enseignementsup-recherche.gouv.fr/explore/dataset/fr-esr-parcoursup](https://data.enseignementsup-recherche.gouv.fr/explore/dataset/fr-esr-parcoursup).
# Commençons par charger les données en utilisant le module pandas (particulièrement adapté en *data science*) en exécutant la case suivante (ce qui peut prendre quelques minutes) :

# %%
import pandas as pd

url = "https://data.enseignementsup-recherche.gouv.fr/explore/dataset/fr-esr-parcoursup/download/?format=csv&timezone=Europe/Berlin&lang=fr&use_labels_for_header=true&csv_separator=%3B" # Lien du dataset

df = pd.read_csv(url, sep=";").iloc[:, [110, 3, 5, 7, 8, 9, 17, 45, 82, 83, 84, 85, 101, 107, 113, 114, 115]]
df = df.rename(columns={"% d’admis néo bacheliers sans mention au bac": "Sans mention", "% d’admis néo bacheliers avec mention Assez Bien au bac": "Mention Assez Bien", "% d’admis néo bacheliers avec mention Bien au bac": "Mention Bien", "% d’admis néo bacheliers avec mention Très Bien au bac": "Mention Très Bien", "Rang du dernier appelé du groupe 1": "Rang dernier appelé", "Taux d’accès des candidats ayant postulé à la formation (ratio entre le dernier appelé et le nombre vœux PP)": "Taux d'accès", "LIB_FOR_VOE_INS": "Filière", "Effectif total des candidats ayant accepté la proposition de l’établissement (admis)": "Effectif"})

# %% [markdown]
# `df` est un *dataframe* : un tableau de données. Voici un aperçu de `df` :

# %%
df
# Out:
#                                                  Filière  \
# 0                  Diplôme de Comptabilité et de Gestion
# 1         BTS - Services - Analyses de biologie médicale
# 2      BTS - Agricole - Analyse, conduite et stratégi...
# 3                           BTS - Agricole - Aquaculture
# 4               BTS - Services - Comptabilité et gestion
# ...                                                  ...
# 13391  Licence - Langues, littératures & civilisation...
# 13392  Licence - Langues, littératures & civilisation...
# 13393  BTS - Production - Métiers du géomètre-topogra...
# 13394  Licence - Langues, littératures & civilisation...
# 13395  Licence - Langues, littératures & civilisation...
#
#                                            Établissement  \
# 0                                   Lycée Sainte Famille
# 1                                     Lycée SAINT JOSEPH
# 2                                         ISETA de Poisy
# 3                                         ISETA de Poisy
# 4                                      Lycée Les Bressis
# ...                                                  ...
# 13391  Aix Marseille Université - Site d'Aix-en-Provence
# 13392               Université Sorbonne Nouvelle Paris 3
# 13393                 Lycée des Métiers Léonard de Vinci
# 13394               Université Sorbonne Nouvelle Paris 3
# 13395               Université Sorbonne Nouvelle Paris 3
#
#       Département de l’établissement Académie de l’établissement  \
# 0                       Haute-Savoie                    Grenoble
# 1                       Haute-Savoie                    Grenoble
# 2                       Haute-Savoie                    Grenoble
# 3                       Haute-Savoie                    Grenoble
# 4                       Haute-Savoie                    Grenoble
# ...                              ...                         ...
# 13391               Bouches-du-Rhône               Aix-Marseille
# 13392                          Paris                       Paris
# 13393                        Gironde                    Bordeaux
# 13394                          Paris                       Paris
# 13395                          Paris                       Paris
#
#       Commune de l’établissement              Sélectivité  \
# 0             La Roche-sur-Foron      formation sélective
# 1               Thonon-les-Bains      formation sélective
# 2                          Poisy      formation sélective
# 3                          Poisy      formation sélective
# 4                         Annecy      formation sélective
# ...                          ...                      ...
# 13391            Aix-en-Provence  formation non sélective
# 13392  Paris  5e  Arrondissement  formation non sélective
# 13393                Blanquefort      formation sélective
# 13394  Paris  5e  Arrondissement  formation non sélective
# 13395  Paris  5e  Arrondissement  formation non sélective
#
#        Effectif total des candidats pour une formation  Effectif  \
# 0                                                  141        19
# 1                                                  374        15
# 2                                                  125        14
# 3                                                  163        32
# 4                                                  174        11
# ...                                                ...       ...
# 13391                                              148        18
# 13392                                              105         8
# 13393                                              497        21
# 13394                                              449        50
# 13395                                             2156        74
#
#        Sans mention  Mention Assez Bien  Mention Bien  Mention Très Bien  \
# 0         18.796875           37.500000     31.296875                6.3
# 1         28.597656           50.000000     21.398438                0.0
# 2         30.796875           30.796875     38.500000                0.0
# 3         32.000000           40.000000     20.000000                0.0
# 4         62.500000           12.500000      0.000000               12.5
# ...             ...                 ...           ...                ...
# 13391     14.298828           35.695312     35.695312               14.3
# 13392     25.000000           50.000000     25.000000                0.0
# 13393     40.000000           55.000000      5.000000                0.0
# 13394      5.099609           43.593750     33.296875               15.4
# 13395      3.199707           27.398438     40.296875               25.8
#
#        Rang dernier appelé  Taux d'accès  \
# 0                     76.0          67.0
# 1                     93.0          25.0
# 2                     11.0          77.0
# 3                     49.0          78.0
# 4                     30.0          89.0
# ...                    ...           ...
# 13391                113.0          80.0
# 13392                 52.0          50.0
# 13393                 78.0          42.0
# 13394                248.0          55.0
# 13395                547.0          25.0
#
#        Dont taux d’accès des candidats ayant un bac général ayant postulé à la formation  \
# 0                                                   53.0
# 1                                                   60.0
# 2                                                   21.0
# 3                                                   47.0
# 4                                                   36.0
# ...                                                  ...
# 13391                                               94.0
# 13392                                               75.0
# 13393                                               33.0
# 13394                                               94.0
# 13395                                               92.0
#
#        Dont taux d’accès des candidats ayant un bac technologique ayant postulé à la formation  \
# 0                                                   47.0
# 1                                                   40.0
# 2                                                   64.0
# 3                                                   31.0
# 4                                                   18.0
# ...                                                  ...
# 13391                                                0.0
# 13392                                               25.0
# 13393                                               19.0
# 13394                                                4.0
# 13395                                                3.0
#
#        Dont taux d’accès des candidats ayant un bac professionnel ayant postulé à la formation
# 0                                                    0.0
# 1                                                    0.0
# 2                                                   14.0
# 3                                                   22.0
# 4                                                   45.0
# ...                                                  ...
# 13391                                                6.0
# 13392                                                0.0
# 13393                                               48.0
# 13394                                                2.0
# 13395                                                5.0
#
# [13396 rows x 17 columns]

# %% [markdown]
# Chaque ligne correspond à une formation (13396 au total) et chaque colonne à un attribut. Par exemple, la première ligne correspond au lycée Sainte Famille	à Grenoble.
# `df.columns` est une liste contenant les noms des colonnes. Par exemple la première colonne est :

# %%
df.columns[0]
# Out:
# 'Filière'

# %% [markdown]
# **Exercice** : Afficher le nom de chaque colonne avec une boucle `for`.

# %% [markdown]
# ## Formation sélective ou non
#
# Une des colonnes de `df` est `"Sélectivité"` et indique si une formation est sélective ou pas (c'est-à-dire si les élèves sont sélectionnés suivant leur dossier) :

# %%
df["Sélectivité"] # liste des sélectivités ("formation sélective" "formation non sélective")
# Out:
# 0            formation sélective
# 1            formation sélective
# 2            formation sélective
# 3            formation sélective
# 4            formation sélective
#                   ...
# 13391    formation non sélective
# 13392    formation non sélective
# 13393        formation sélective
# 13394    formation non sélective
# 13395    formation non sélective
# Name: Sélectivité, Length: 13396, dtype: object

# %%
df["Sélectivité"][0] # indique la sélectivité de la 1ère formation
# Out:
# 'formation sélective'

# %% [markdown]
# **Exercice** : Calculer le pourcentage de formations sélectives.

# %% [markdown]
# # Lycée Fénelon Sainte-Marie

# %% [markdown]
# Pour chercher des valeurs, on peut utiliser `query`. Par exemple, l'instruction suivante permet de récupérer toutes les MP2I de France :

# %%
df.query("Filière == 'CPGE - MP2I'")
# Out:
#            Filière                    Établissement  \
# 2297   CPGE - MP2I                Lycée Paul Valery
# 2338   CPGE - MP2I                Lycée Victor Hugo
# 2340   CPGE - MP2I                  Lycée Faidherbe
# 2341   CPGE - MP2I               Lycée Henri Wallon
# 2342   CPGE - MP2I       Lycée Fénelon Sainte-Marie
# 2343   CPGE - MP2I           Lycée Pierre De Fermat
# 5332   CPGE - MP2I            Lycée Charles Coeffin
# 5333   CPGE - MP2I                    Lycée Colbert
# 5334   CPGE - MP2I                    Lycée du Parc
# 5372   CPGE - MP2I                     Lycée Carnot
# 5374   CPGE - MP2I             Lycée Louis Le Grand
# 7012   CPGE - MP2I                     Lycée Kléber
# 7050   CPGE - MP2I                Lycée Champollion
# 7051   CPGE - MP2I         Lycée général Clemenceau
# 7052   CPGE - MP2I  Lycée International de Valbonne
# 9832   CPGE - MP2I                     Lycée Thiers
# 9836   CPGE - MP2I             Lycée Claude Fauriel
# 9838   CPGE - MP2I                  Lycée Descartes
# 9840   CPGE - MP2I           Lycée Janson De Sailly
# 11980  CPGE - MP2I                 Lycée Gay-Lussac
# 11981  CPGE - MP2I         Lycée Franklin Roosevelt
# 12019  CPGE - MP2I            Lycée Louis Thuillier
# 12020  CPGE - MP2I                  Lycée Montaigne
# 12021  CPGE - MP2I             Lycée Aux Lazaristes
# 12022  CPGE - MP2I         Lycée Saint-Louis (6ème)
# 12023  CPGE - MP2I                      Lycée Hoche
#
#       Département de l’établissement Académie de l’établissement  \
# 2297                           Paris                       Paris
# 2338                           Doubs                    Besancon
# 2340                            Nord                       Lille
# 2341                            Nord                       Lille
# 2342                           Paris                       Paris
# 2343                   Haute-Garonne                    Toulouse
# 5332                      Guadeloupe                  Guadeloupe
# 5333                            Nord                       Lille
# 5334                           Rhône                        Lyon
# 5372                       Côte-d'or                       Dijon
# 5374                           Paris                       Paris
# 7012                        Bas-Rhin                  Strasbourg
# 7050                           Isère                    Grenoble
# 7051                Loire-Atlantique                      Nantes
# 7052                 Alpes-Maritimes                        Nice
# 9832                Bouches-du-Rhône               Aix-Marseille
# 9836                           Loire                        Lyon
# 9838                  Indre-et-Loire               Orléans-Tours
# 9840                           Paris                       Paris
# 11980                   Haute-Vienne                     Limoges
# 11981                          Marne                       Reims
# 12019                          Somme                      Amiens
# 12020                        Gironde                    Bordeaux
# 12021                          Rhône                        Lyon
# 12022                          Paris                       Paris
# 12023                       Yvelines                  Versailles
#
#           Commune de l’établissement          Sélectivité  \
# 2297       Paris 12e  Arrondissement  formation sélective
# 2338                        Besançon  formation sélective
# 2340                           Lille  formation sélective
# 2341                    Valenciennes  formation sélective
# 2342       Paris  8e  Arrondissement  formation sélective
# 2343                        Toulouse  formation sélective
# 5332                    Baie-Mahault  formation sélective
# 5333                       Tourcoing  formation sélective
# 5334         Lyon 6e  Arrondissement  formation sélective
# 5372                           Dijon  formation sélective
# 5374       Paris  5e  Arrondissement  formation sélective
# 7012                      Strasbourg  formation sélective
# 7050                        Grenoble  formation sélective
# 7051                          Nantes  formation sélective
# 7052                        Valbonne  formation sélective
# 9832   Marseille  1er Arrondissement  formation sélective
# 9836                   Saint-Etienne  formation sélective
# 9838                           Tours  formation sélective
# 9840       Paris 16e  Arrondissement  formation sélective
# 11980                        Limoges  formation sélective
# 11981                          Reims  formation sélective
# 12019                         Amiens  formation sélective
# 12020                       Bordeaux  formation sélective
# 12021        Lyon 5e  Arrondissement  formation sélective
# 12022      Paris  6e  Arrondissement  formation sélective
# 12023                     Versailles  formation sélective
#
#        Effectif total des candidats pour une formation  Effectif  \
# 2297                                              1705        49
# 2338                                               750        42
# 2340                                              1309        47
# 2341                                               679        24
# 2342                                              1384        43
# 2343                                              2234        48
# 5332                                               160        20
# 5333                                               433        18
# 5334                                              2551        46
# 5372                                              1233        46
# 5374                                              2970        47
# 7012                                              1207        46
# 7050                                              1672        48
# 7051                                              1837        48
# 7052                                               844        47
# 9832                                              1247        48
# 9836                                               881        47
# 9838                                              1562        46
# 9840                                              2931        50
# 11980                                              664        23
# 11981                                              702        45
# 12019                                              851        37
# 12020                                             1994        48
# 12021                                             1240        12
# 12022                                             3057        46
# 12023                                             2102        48
#
#        Sans mention  Mention Assez Bien  Mention Bien  Mention Très Bien  \
# 2297       2.099609           36.195312     44.695312               14.9
# 2338       0.000000           23.796875     42.898438               26.2
# 2340       0.000000            0.000000     17.398438               58.7
# 2341       0.000000            8.298828     54.195312               33.3
# 2342       0.000000            2.299805     55.796875               41.9
# 2343       0.000000            0.000000      2.099609               68.1
# 5332      17.597656           35.296875     35.296875               11.8
# 5333       0.000000           15.398438     53.796875               23.1
# 5334       0.000000            0.000000      0.000000               62.2
# 5372       0.000000           13.000000     67.390625               17.4
# 5374       0.000000            0.000000      8.699219               47.8
# 7012       0.000000            2.199707     34.796875               58.7
# 7050       0.000000            2.099609     34.000000               59.6
# 7051       0.000000            0.000000     12.798828               68.1
# 7052       0.000000           14.898438     44.695312               36.2
# 9832       0.000000            0.000000     28.296875               71.7
# 9836       0.000000           19.097656     48.898438               31.9
# 9838       0.000000            0.000000     31.097656               62.2
# 9840       0.000000            0.000000     30.000000               62.0
# 11980      0.000000            0.000000     52.195312               43.5
# 11981      2.299805           23.296875     58.093750               16.3
# 12019      0.000000            2.899902     65.687500               25.7
# 12020      0.000000            0.000000     29.199219               62.5
# 12021      0.000000            0.000000      0.000000               50.0
# 12022      0.000000            0.000000      8.699219               69.6
# 12023      0.000000            0.000000     22.898438               52.1
#
#        Rang dernier appelé  Taux d'accès  \
# 2297                 767.0          45.0
# 2338                 401.0          53.0
# 2340                 297.0          23.0
# 2341                 250.0          37.0
# 2342                 366.0          26.0
# 2343                 285.0          13.0
# 5332                 107.0          74.0
# 5333                 238.0          55.0
# 5334                 344.0          13.0
# 5372                 483.0          41.0
# 5374                 127.0           4.0
# 7012                 224.0          19.0
# 7050                 269.0          16.0
# 7051                 229.0          12.0
# 7052                 324.0          38.0
# 9832                 305.0          24.0
# 9836                 456.0          52.0
# 9838                 329.0          21.0
# 9840                 379.0          13.0
# 11980                254.0          38.0
# 11981                393.0          56.0
# 12019                274.0          35.0
# 12020                299.0          15.0
# 12021                141.0          11.0
# 12022                278.0           9.0
# 12023                193.0           9.0
#
#        Dont taux d’accès des candidats ayant un bac général ayant postulé à la formation  \
# 2297                                                98.0
# 2338                                               100.0
# 2340                                               100.0
# 2341                                               100.0
# 2342                                               100.0
# 2343                                               100.0
# 5332                                               100.0
# 5333                                               100.0
# 5334                                               100.0
# 5372                                               100.0
# 5374                                               100.0
# 7012                                               100.0
# 7050                                               100.0
# 7051                                               100.0
# 7052                                               100.0
# 9832                                               100.0
# 9836                                               100.0
# 9838                                               100.0
# 9840                                               100.0
# 11980                                              100.0
# 11981                                              100.0
# 12019                                              100.0
# 12020                                              100.0
# 12021                                              100.0
# 12022                                              100.0
# 12023                                              100.0
#
#        Dont taux d’accès des candidats ayant un bac technologique ayant postulé à la formation  \
# 2297                                                 2.0
# 2338                                                 0.0
# 2340                                                 0.0
# 2341                                                 0.0
# 2342                                                 0.0
# 2343                                                 0.0
# 5332                                                 0.0
# 5333                                                 0.0
# 5334                                                 0.0
# 5372                                                 0.0
# 5374                                                 0.0
# 7012                                                 0.0
# 7050                                                 0.0
# 7051                                                 0.0
# 7052                                                 0.0
# 9832                                                 0.0
# 9836                                                 0.0
# 9838                                                 0.0
# 9840                                                 0.0
# 11980                                                0.0
# 11981                                                0.0
# 12019                                                0.0
# 12020                                                0.0
# 12021                                                0.0
# 12022                                                0.0
# 12023                                                0.0
#
#        Dont taux d’accès des candidats ayant un bac professionnel ayant postulé à la formation
# 2297                                                 0.0
# 2338                                                 0.0
# 2340                                                 0.0
# 2341                                                 0.0
# 2342                                                 0.0
# 2343                                                 0.0
# 5332                                                 0.0
# 5333                                                 0.0
# 5334                                                 0.0
# 5372                                                 0.0
# 5374                                                 0.0
# 7012                                                 0.0
# 7050                                                 0.0
# 7051                                                 0.0
# 7052                                                 0.0
# 9832                                                 0.0
# 9836                                                 0.0
# 9838                                                 0.0
# 9840                                                 0.0
# 11980                                                0.0
# 11981                                                0.0
# 12019                                                0.0
# 12020                                                0.0
# 12021                                                0.0
# 12022                                                0.0
# 12023                                                0.0

# %% [markdown]
# **Exercice** : Quelles sont les MP2I avec le plus/le moins d'élèves ?

# %% [markdown]
# **Exercice** : En utilisant `df.query` de façon similaire à ci-dessus, chercher toutes les formations correpondants à l'établissement "Lycée Fénelon Sainte-Marie". Quelle est la filière du lycée avec le plus de mentions TB ?

# %% [markdown]
# ## Effectif

# %% [markdown]
# `df["Effectif"]` donne l'effectif (nombre d'élèves) de chaque formation. Par exemple, pour obtenir l'effectif de la première formation :

# %%
df["Effectif"][0]
# Out:
# 19

# %% [markdown]
# **Exercice** : Quel est l'effectif moyen d'une formation en France ?

# %% [markdown]
# **Exercice** : Calculer l'effectif maximum et minimum d'une formation en France. Quels sont les noms des filières correspondantes ?

# %% [markdown]
# ## Filières en CPGE

# %% [markdown]
# On peut tester si une chaîne de caractère contient un mot en utilisant `in` :

# %%
"mat" in "informatique"
# Out:
# True

# %%
"math" in "informatique"
# Out:
# False

# %% [markdown]
# **Exercice** : Quel est le nombre de CPGE en France ? Et pour chaque filière de CPGE (MPSI, PCSI, MP2I, BCPST...) ?

# %% [markdown]
# ## Pourcentage de mentions Très Bien

# %% [markdown]
# **Exercice** : Combien y a t-il eu de mentions TB en France ?
# *Indice* : Il faut multiplier chaque pourcentage de mentions TB par l'effectif de la formation, puis prendre la somme.

# %% [markdown]
# # À vous de jouer !
#
# Chercher d'autres statistiques sur les données : pourcentage de bacheliers technologiques dans le supérieur, filière de CPGE la plus sélective...
# Vous pouvez aussi explorer d'autres données sur https://data.enseignementsup-recherche.gouv.fr.
